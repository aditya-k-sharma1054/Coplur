# %%
a=2
b=-3
print(a*b)
# Out:
# -6

# %%
a-b
# Out:
# 5

# %%
str(a)
a
# Out:
# 2

# %%
print("Hello",'python','world',sep=" -", 
      end='z       '         )
print('''jhgfd
      
      
      sa''')

#print(a-b)
print(type(a))
type(b)
print(id(b))
b = str(b)
print(b)
print(id(b))
print(b)
print(type(b))
# Out:
# Hello -python -worldz       jhgfd
#
#
#       sa
# <class 'int'>
# 1517548309696
# -3.0
# 1517548309696
# -3.0
# <class 'str'>

# %%
n=input("Enter a number: ")
print(n)
print(type(n))
len(n)
# Out:
# j
# <class 'str'>
# 1

# %%
len(n)
'''
fsdiufhsiohfiofhfhisl
   hjgvygjbhjbj
        khgiygghkkbhkj
'''
#                   fff
# Out:
# '\nfsdiufhsiohfiofhfhisl\n   hjgvygjbhjbj\n        khgiygghkkbhkj\n'

# %%
print('asdasdasd') 
;  print('efqwfqwefqwfqqwef')
# Out:
# asdasdasd
# " print('efqwfqwefqwfqqwef')"

# %%
pr=39999
tx=797979
print(f"price is {pr} dollars")
print(f"tax is {tx: .2f} dollars")
# Out:
# price is 39999 dollars
# tax is  797979.00 dollars

# %%
print(("dsadaasd efefw wefwefw wefwef".title()).lower())
# Out:
# dsadaasd efefw wefwefw wefwef

# %%
o='0TYdtdg3@ fh0'
print(o.center(66,'e'))
print(o.count("r")); len(o)
print(o.find("x")); #print(o.index("x"))
print(o.isalnum()); print(o.isalpha())
# Out:
# eeeeeeeeeeeeeeeeeeeeeeeeee0TYdtdg3@ fh0eeeeeeeeeeeeeeeeeeeeeeeeeee
# 0
# -1
# False
# False

# %%
print(o.rjust(22, 'u')); print(o.ljust(22, 'u'))
print(o.strip('0')); print(o.lstrip('0')); print(o.rstrip('0'))
# Out:
# uuuuuuuuu0TYdtdg3@ fh0
# 0TYdtdg3@ fh0uuuuuuuuu
# TYdtdg3@ fh
# TYdtdg3@ fh0
# 0TYdtdg3@ fh

# %%
print(o.split(' ')); print(o.split('@'))
print(o.replace('0', 'u')); print(o.replace('0', 'u',1))
# Out:
# ['0TYdtdg3@', 'fh0']
# ['0TYdtdg3', ' fh0']
# uTYdtdg3@ fhu
# uTYdtdg3@ fh0

# %%
print(o.startswith('0')); print(o.endswith('0'));print(o.isdigit())
print(o.isprintable())
# Out:
# True
# True
# False
# True

# %%
print(o.isspace()); print(o.partition('d')); print(o.rpartition('d'))
print(o.capitalize()); print(o.swapcase())
# Out:
# False
# ('0TY', 'd', 'tdg3@ fh0')
# ('0TYdt', 'd', 'g3@ fh0')
# 0tydtdg3@ fh0
# 0tyDTDG3@ FH0

# %%
print(o.translate(str.maketrans('d', 'X')))
print(o.translate(str.maketrans('0T', 'uU', '0TYtg@h0 ')))
# Out:
# 0TYXtXg3@ fh0
# dd3f

# %%
top=122
top=~top
top=not top
top
# Out:
# False

# %%
l='x'
print(l in o)
# Out:
# False

# %%
for i in range(100,-1,-50):    # initial, final, stepsize
    if(i>=50):
        print(i)
    print(~i)
# Out:
# 100
# -101
# 50
# -51
# -1

# %%
for i in range(100,-1,-50):    
    pass

# %%
num=int(input("Enter a number: "))
for i in range(1,11,1):
    print(f"{num} x {i} = {num*i}")
# Out:
# 17 x 1 = 17
# 17 x 2 = 34
# 17 x 3 = 51
# 17 x 4 = 68
# 17 x 5 = 85
# 17 x 6 = 102
# 17 x 7 = 119
# 17 x 8 = 136
# 17 x 9 = 153
# 17 x 10 = 170

# %%
for i in range(0,3):
    for j in range(-3,0):
        print(i,j,sep=',',end='\n')
        break
# Out:
# 0,-3
# 1,-3
# 2,-3

# %%
str='bahubali'
print(str[:-9:78])
print(str[-8]); print(str[7])
# Out:
# b
# i

# %%
str = 'python program'
for x in str:
    print(x)
print(len(str)); print(str.count('p'))
print(ord('A')); print(chr(1509))
# Out:
# p
# y
# t
# h
# o
# n
#
# p
# r
# o
# g
# r
# a
# m
# 14
# 2
# 65
# ץ
