# %%
import pandas as pd

sheet = [
    [12, "Ravi", 78],
    [15, "Mira", 83],
    [18, "Zoya", 91]
]

pd.DataFrame(sheet, columns=["Roll", "Name", "Score"])
# Out:
#    Roll  Name  Score
# 0    12  Ravi     78
# 1    15  Mira     83
# 2    18  Zoya     91

# %%
import pandas as pd

bag = {
    "Snack": ["Chips", "Cake", "Juice"],
    "Qty": [4, 2, 5]
}

pd.DataFrame(bag)
# Out:
#    Snack  Qty
# 0  Chips    4
# 1   Cake    2
# 2  Juice    5

# %%
import pandas as pd

mix = [
    ["Red", 23],
    ["Blue", 17],
    ["Black", 31]
]

pd.DataFrame(mix, columns=["Shade", "Count"])
# Out:
#    Shade  Count
# 0    Red     23
# 1   Blue     17
# 2  Black     31

# %%
import pandas as pd

pair = [
    ("Ishan", 67),
    ("Ritu", 74),
    ("Dev", 81)
]

pd.DataFrame(pair, columns=["Name", "Marks"])
# Out:
#     Name  Marks
# 0  Ishan     67
# 1   Ritu     74
# 2    Dev     81

# %%
import pandas as pd

rows = [
    {"Item": "Pen", "Price": 12},
    {"Item": "Book", "Price": 45},
    {"Item": "Scale", "Price": 18}
]

pd.DataFrame(rows)
# Out:
#     Item  Price
# 0    Pen     12
# 1   Book     45
# 2  Scale     18
