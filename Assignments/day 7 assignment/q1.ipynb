# %%
import pandas as pd

marks = {
    "Aru": 78,
    "Neel": 91,
    "Tia": 84,
    "Kabir": 88
}

pd.Series(marks)
# Out:
# Aru      78
# Neel     91
# Tia      84
# Kabir    88
# dtype: int64

# %%
import pandas as pd

cities = ["Jaipur", "Pune", "Indore", "Surat"]

pd.Series(cities)
# Out:
# 0    Jaipur
# 1      Pune
# 2    Indore
# 3     Surat
# dtype: str

# %%
import pandas as pd

temps = pd.Series([29, 31, 33, 28], index=["Mon", "Tue", "Wed", "Thu"])

print(temps["Wed"])
print(temps.iloc[1])
# Out:
# 33
# 31
