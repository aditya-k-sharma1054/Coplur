# %%
import pandas as pd
d=['2024-01-01','2024-01-05','2024-02-10','2024-03-15']
t=pd.to_datetime(d)
s=pd.Series(t)
print(s)
# Out:
# 0   2024-01-01
# 1   2024-01-05
# 2   2024-02-10
# 3   2024-03-15
# dtype: datetime64[us]
